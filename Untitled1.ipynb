# %%
import pandas as pd
from urdu import lig_to_rom as lr

# %%
df= pd.read_csv('urdu.csv')
df.Urdu
# Out:
# 0          آب
# 1         آبا
# 2         ابا
# 3      ابابیل
# 4       اباحت
#         ...
# 148     اجسام
# 149     اَجَل
# 150     اَجَل
# 151     اَجگر
# 152     اُجلا
# Name: Urdu, Length: 153, dtype: object

# %%
for i in df.Urdu:
    print(lr.lig_to_roman(i))
# Out:
# AAB
# AABA
# ABA
# ABABIL
# ABAHT
# ABAL
# ABALA
# ABALNA
# ABTDA
# ABTDAYI
# ABTDAYIH
# ABTDAL
# ABTR
# ABTLA
# ABTHAJ
# ABTN
# AABJD
# ANJRH
# AABD
# ABDAL
# AAIDI
# AABDIT
# ABR
# AABRA
# AABRAR
# ABRAM
# ABRAHIM
# ABRS
# ABRQ
# AABRK
# ABRN
# AABRO
# AABRO
# AABRI
# ABRISHM
# ABSNA
# ABSAR
# أBTAL
# AIKANI
# ABLA
# ABHIAS
# AOPAS
# APAHJ
# AOPAۓ
# APCH
# APJAO
# AGCHNA
# APDISH
# APDISHK
# APRADH
# APRADHI
# APRM PAR
# APRIL
# APSRA
# APKAR
# APLA
# APMAN
# APNA
# AُTARN
# AُTRN
# ATARNA
# ATARO
# ATASHI
# ATALIQ
# ATA OLA
# AATAYI
# ATBAA
# ATHAD
# AُTR
# AُTRA
# AِTRANA
# AُTRANA
# ATRAYI
# AَTَRSُON
# AُTRN
# AُTRNA
# AُTSAH
# ATSَO
# AِTّSAL
# AِTّSALI
# AِTّFAQ
# AِTّFAQAً
# AِTّFAQAT
# ATّFAQIH
# AِTQA
# AَTQIA
# ATLAF
# AُTM
# AِTMAM
# AِTNA
# AُTّO
# APOZISHN
# AُPON
# AُPHAR
# AُPI
# APIL
# APIL
# APILANT
# AَPHَAR
# APHRNA
# AَTَAPTَA
# AُTAR
# AُTARA
# AَTHّA
# ATHARH
# ATHASI
# AُTHAN
# AُTHANA
# AَTHّANOE
# AَTHّAON
# ATHLANA
# AَTHِNّI
# AَTHOANSA
# AَSASH
# AِSBAT
# ...

# %%
M i alowed to upoad ?
pip
yes/no
